# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\Documents\DEE\Analyst Portfolio\life expectancy.csv")
data
# Out:
#               Country Name Country Code                      Region  \
# 0              Afghanistan          AFG                  South Asia
# 1                   Angola          AGO          Sub-Saharan Africa
# 2                  Albania          ALB       Europe & Central Asia
# 3                  Andorra          AND       Europe & Central Asia
# 4     United Arab Emirates          ARE  Middle East & North Africa
# ...                    ...          ...                         ...
# 3301               Vanuatu          VUT         East Asia & Pacific
# 3302                 Samoa          WSM         East Asia & Pacific
# 3303          South Africa          ZAF          Sub-Saharan Africa
# 3304                Zambia          ZMB          Sub-Saharan Africa
# 3305              Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup  Year  Life Expectancy World Bank  \
# 0              Low income  2001                      56.308
# ...

# %%
#filtering using the region column to focus on sub-saharan africa

africa = ['Sub-Saharan Africa']
SSA = data[data['Region'] .isin(africa)]
SSA
# Out:
#       Country Name Country Code              Region          IncomeGroup  \
# 1           Angola          AGO  Sub-Saharan Africa  Lower middle income
# 12         Burundi          BDI  Sub-Saharan Africa           Low income
# 14           Benin          BEN  Sub-Saharan Africa  Lower middle income
# 15    Burkina Faso          BFA  Sub-Saharan Africa           Low income
# 27        Botswana          BWA  Sub-Saharan Africa  Upper middle income
# ...            ...          ...                 ...                  ...
# 3294      Tanzania          TZA  Sub-Saharan Africa  Lower middle income
# 3295        Uganda          UGA  Sub-Saharan Africa           Low income
# 3303  South Africa          ZAF  Sub-Saharan Africa  Upper middle income
# 3304        Zambia          ZMB  Sub-Saharan Africa           Low income
# 3305      Zimbabwe          ZWE  Sub-Saharan Africa  Lower middle income
#
#       Year  Life Expectancy World Bank  Prevelance of Undernourishment  \
# ...

# %%
#Taking a look at the data

SSA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836 entries, 1 to 3305
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country Name                    836 non-null    object
#  1   Country Code                    836 non-null    object
#  2   Region                          836 non-null    object
#  3   IncomeGroup                     836 non-null    object
#  4   Year                            836 non-null    int64
#  5   Life Expectancy World Bank      836 non-null    float64
#  6   Prevelance of Undernourishment  608 non-null    float64
#  7   CO2                             836 non-null    float64
#  8   Health Expenditure %            792 non-null    float64
#  9   Education Expenditure %         578 non-null    float64
#  10  Unemployment                    817 non-null    float64
#  11  Corruption                      510 non-null    float64
# ...

# %%
SSA.describe()
# Out:
#               Year  Life Expectancy World Bank  \
# count   836.000000                  836.000000
# mean   2010.000000                   57.542669
# std       5.480504                    6.849969
# min    2001.000000                   40.369000
# 25%    2005.000000                   52.742750
# 50%    2010.000000                   57.488500
# 75%    2015.000000                   62.018750
# max    2019.000000                   74.514634
#
#        Prevelance of Undernourishment            CO2  Health Expenditure %  \
# count                      608.000000     836.000000            792.000000
# mean                        21.456579   15456.267976              5.515554
# std                         14.244048   61422.258160              2.344765
# min                          3.100000      50.000000              1.263576
# 25%                         10.900000     680.000007              3.852710
# 50%                         18.200000    2460.000019              4.975396
# ...

# %%
SSA.isnull().sum()
# Out:
# Country Name                        0
# Country Code                        0
# Region                              0
# IncomeGroup                         0
# Year                                0
# Life Expectancy World Bank          0
# Prevelance of Undernourishment    228
# CO2                                 0
# Health Expenditure %               44
# Education Expenditure %           258
# Unemployment                       19
# Corruption                        326
# Sanitation                        494
# Injuries                            0
# Communicable                        0
# NonCommunicable                     0
# dtype: int64

# %%
SSA.groupby('Year').agg({'Education Expenditure %' : ['mean']})
# Out:
#      Education Expenditure %
#                         mean
# Year
# 2001                3.767954
# 2002                3.544882
# 2003                4.010034
# 2004                3.731874
# 2005                4.103735
# 2006                3.930848
# 2007                3.695013
# 2008                3.777423
# 2009                4.033060
# 2010                3.985509
# 2011                3.997148
# 2012                3.857585
# 2013                3.946136
# 2014                4.161266
# 2015                4.260035
# 2016                4.064339
# 2017                4.271439
# 2018                4.189494
# 2019                4.203542

# %%
#filling missing values in the data by columns
SSA
# Out:
#       Country Name Country Code              Region          IncomeGroup  \
# 1           Angola          AGO  Sub-Saharan Africa  Lower middle income
# 12         Burundi          BDI  Sub-Saharan Africa           Low income
# 14           Benin          BEN  Sub-Saharan Africa  Lower middle income
# 15    Burkina Faso          BFA  Sub-Saharan Africa           Low income
# 27        Botswana          BWA  Sub-Saharan Africa  Upper middle income
# ...            ...          ...                 ...                  ...
# 3294      Tanzania          TZA  Sub-Saharan Africa  Lower middle income
# 3295        Uganda          UGA  Sub-Saharan Africa           Low income
# 3303  South Africa          ZAF  Sub-Saharan Africa  Upper middle income
# 3304        Zambia          ZMB  Sub-Saharan Africa           Low income
# 3305      Zimbabwe          ZWE  Sub-Saharan Africa  Lower middle income
#
#       Year  Life Expectancy World Bank  Prevelance of Undernourishment  \
# ...

# %%
SSA['Prevelance of Undernourishment'] = SSA.groupby('Year')['Prevelance of Undernourishment'].apply(lambda x: x.fillna(x.mean()))
SSA
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_6568/1822159153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SSA['Prevelance of Undernourishment'] = SSA.groupby('Year')['Prevelance of Undernourishment'].apply(lambda x: x.fillna(x.mean()))
#       Country Name Country Code              Region          IncomeGroup  \
# 1           Angola          AGO  Sub-Saharan Africa  Lower middle income
# 12         Burundi          BDI  Sub-Saharan Africa           Low income
# 14           Benin          BEN  Sub-Saharan Africa  Lower middle income
# 15    Burkina Faso          BFA  Sub-Saharan Africa           Low income
# 27        Botswana          BWA  Sub-Saharan Africa  Upper middle income
# ...

# %%
SSA['Health Expenditure %'] = SSA.groupby('Year')['Health Expenditure %'].apply(lambda x: x.fillna(x.mean()))
SSA['Education Expenditure %'] = SSA.groupby('Year')['Education Expenditure %'].apply(lambda x: x.fillna(x.mean()))
SSA['Unemployment'] = SSA.groupby('Year')['Unemployment'].apply(lambda x: x.fillna(x.mean()))
SSA['Sanitation'] = SSA.groupby('Year')['Sanitation'].apply(lambda x: x.fillna(x.mean()))
SSA['Corruption'] = SSA['Corruption'].fillna(0)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_6568/2190535230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SSA['Health Expenditure %'] = SSA.groupby('Year')['Health Expenditure %'].apply(lambda x: x.fillna(x.mean()))
# C:\Users\user\AppData\Local\Temp/ipykernel_6568/2190535230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SSA['Education Expenditure %'] = SSA.groupby('Year')['Education Expenditure %'].apply(lambda x: x.fillna(x.mean()))
# ...

# %%
SSA.isnull().sum()
# Out:
# Country Name                      0
# Country Code                      0
# Region                            0
# IncomeGroup                       0
# Year                              0
# Life Expectancy World Bank        0
# Prevelance of Undernourishment    0
# CO2                               0
# Health Expenditure %              0
# Education Expenditure %           0
# Unemployment                      0
# Corruption                        0
# Sanitation                        0
# Injuries                          0
# Communicable                      0
# NonCommunicable                   0
# dtype: int64

# %%
pd.set_option('display.max.rows', 836)

# %%
SSA
# Out:
#                   Country Name Country Code              Region  \
# 1                       Angola          AGO  Sub-Saharan Africa
# 12                     Burundi          BDI  Sub-Saharan Africa
# 14                       Benin          BEN  Sub-Saharan Africa
# 15                Burkina Faso          BFA  Sub-Saharan Africa
# 27                    Botswana          BWA  Sub-Saharan Africa
# 28    Central African Republic          CAF  Sub-Saharan Africa
# 33               Cote d'Ivoire          CIV  Sub-Saharan Africa
# 34                    Cameroon          CMR  Sub-Saharan Africa
# 36                     Comoros          COM  Sub-Saharan Africa
# 47                     Eritrea          ERI  Sub-Saharan Africa
# 50                    Ethiopia          ETH  Sub-Saharan Africa
# 54                       Gabon          GAB  Sub-Saharan Africa
# 57                       Ghana          GHA  Sub-Saharan Africa
# 58                      Guinea          GIN  Sub-Saharan Africa
# ...

# %%
SSA.reset_index(drop = True)
# Out:
#                  Country Name Country Code              Region  \
# 0                      Angola          AGO  Sub-Saharan Africa
# 1                     Burundi          BDI  Sub-Saharan Africa
# 2                       Benin          BEN  Sub-Saharan Africa
# 3                Burkina Faso          BFA  Sub-Saharan Africa
# 4                    Botswana          BWA  Sub-Saharan Africa
# 5    Central African Republic          CAF  Sub-Saharan Africa
# 6               Cote d'Ivoire          CIV  Sub-Saharan Africa
# 7                    Cameroon          CMR  Sub-Saharan Africa
# 8                     Comoros          COM  Sub-Saharan Africa
# 9                     Eritrea          ERI  Sub-Saharan Africa
# 10                   Ethiopia          ETH  Sub-Saharan Africa
# 11                      Gabon          GAB  Sub-Saharan Africa
# 12                      Ghana          GHA  Sub-Saharan Africa
# 13                     Guinea          GIN  Sub-Saharan Africa
# ...

# %%
#DATA EXPLORATION

# %%
#looking at correlations
SSA.corr()
# Out:
#                                     Year  Life Expectancy World Bank  \
# Year                            1.000000                    0.509808
# Life Expectancy World Bank      0.509808                    1.000000
# Prevelance of Undernourishment -0.192955                   -0.297808
# CO2                             0.031991                    0.000764
# Health Expenditure %            0.057360                   -0.131970
# Education Expenditure %         0.091815                    0.044100
# Unemployment                   -0.024453                   -0.071887
# Corruption                      0.437874                    0.147675
# Sanitation                      0.462218                    0.097890
# Injuries                        0.018800                   -0.119960
# Communicable                   -0.069698                   -0.225113
# NonCommunicable                 0.069218                   -0.084732
#
# ...
